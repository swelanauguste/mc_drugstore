# %%
import pandas as pd

# %%
df = pd.read_csv("products.csv")
df.shape
# Out:
# (13967, 5)

# %%
df=df.drop_duplicates()
df.shape
# Out:
# (6912, 5)

# %%
df.head()
# Out:
#         Anthisan Bite & Sting Cream 25g  Non-Prescribed Drugs  27.75  \
# 0                Arcalion Tablets 200mg              Pharmacy   3.50
# 1                   Bactin Ointment 15g  Non-Prescribed Drugs  12.10
# 2  Becoplex With Iron Capsules 30 count  Non-Prescribed Drugs  22.16
# 3      Becoplex Liquid Iron Syrup 125ml  Non-Prescribed Drugs  19.80
# 4                  Becoplex Syrup 125ml  Non-Prescribed Drugs  18.30
#
#   https://mandcdrugstore.com/files/images/thumbs/ded5156a8bbd88877ae96f62b9683992.jpg  \
# 0  https://mandcdrugstore.com/files/images/thumbs...
# 1  https://mandcdrugstore.com/files/images/thumbs...
# 2  https://mandcdrugstore.com/files/images/thumbs...
# 3  https://mandcdrugstore.com/files/images/thumbs...
# 4  https://mandcdrugstore.com/files/images/thumbs...
#
#    https://mandcdrugstore.com/products/1
# 0  https://mandcdrugstore.com/products/2
# 1  https://mandcdrugstore.com/products/3
# 2  https://mandcdrugstore.com/products/4
# ...

# %%
df2=df
df2.columns =["name", "category", "price", "img_url", "url"]
df2.head()
# Out:
#                                    name              category  price  \
# 0                Arcalion Tablets 200mg              Pharmacy   3.50
# 1                   Bactin Ointment 15g  Non-Prescribed Drugs  12.10
# 2  Becoplex With Iron Capsules 30 count  Non-Prescribed Drugs  22.16
# 3      Becoplex Liquid Iron Syrup 125ml  Non-Prescribed Drugs  19.80
# 4                  Becoplex Syrup 125ml  Non-Prescribed Drugs  18.30
#
#                                              img_url  \
# 0  https://mandcdrugstore.com/files/images/thumbs...
# 1  https://mandcdrugstore.com/files/images/thumbs...
# 2  https://mandcdrugstore.com/files/images/thumbs...
# 3  https://mandcdrugstore.com/files/images/thumbs...
# 4  https://mandcdrugstore.com/files/images/thumbs...
#
#                                      url
# 0  https://mandcdrugstore.com/products/2
# 1  https://mandcdrugstore.com/products/3
# 2  https://mandcdrugstore.com/products/4
# 3  https://mandcdrugstore.com/products/5
# ...

# %%
df2=df

# %%
df.head()
# Out:
#                                    name              category  price  \
# 0                Arcalion Tablets 200mg              Pharmacy   3.50
# 1                   Bactin Ointment 15g  Non-Prescribed Drugs  12.10
# 2  Becoplex With Iron Capsules 30 count  Non-Prescribed Drugs  22.16
# 3      Becoplex Liquid Iron Syrup 125ml  Non-Prescribed Drugs  19.80
# 4                  Becoplex Syrup 125ml  Non-Prescribed Drugs  18.30
#
#                                              img_url  \
# 0  https://mandcdrugstore.com/files/images/thumbs...
# 1  https://mandcdrugstore.com/files/images/thumbs...
# 2  https://mandcdrugstore.com/files/images/thumbs...
# 3  https://mandcdrugstore.com/files/images/thumbs...
# 4  https://mandcdrugstore.com/files/images/thumbs...
#
#                                      url
# 0  https://mandcdrugstore.com/products/2
# 1  https://mandcdrugstore.com/products/3
# 2  https://mandcdrugstore.com/products/4
# 3  https://mandcdrugstore.com/products/5
# ...

# %%
df2=df

# %%
df2['product_id'] = df2['url'].astype(str)

# %%
df2.head()
# Out:
#                                    name              category  price  \
# 0                Arcalion Tablets 200mg              Pharmacy   3.50
# 1                   Bactin Ointment 15g  Non-Prescribed Drugs  12.10
# 2  Becoplex With Iron Capsules 30 count  Non-Prescribed Drugs  22.16
# 3      Becoplex Liquid Iron Syrup 125ml  Non-Prescribed Drugs  19.80
# 4                  Becoplex Syrup 125ml  Non-Prescribed Drugs  18.30
#
#                                              img_url  \
# 0  https://mandcdrugstore.com/files/images/thumbs...
# 1  https://mandcdrugstore.com/files/images/thumbs...
# 2  https://mandcdrugstore.com/files/images/thumbs...
# 3  https://mandcdrugstore.com/files/images/thumbs...
# 4  https://mandcdrugstore.com/files/images/thumbs...
#
#                                      url  \
# 0  https://mandcdrugstore.com/products/2
# 1  https://mandcdrugstore.com/products/3
# 2  https://mandcdrugstore.com/products/4
# 3  https://mandcdrugstore.com/products/5
# ...

# %%
df2['product_id'] = df2['product_id'].str.replace("https://mandcdrugstore.com/products/", "")

# %%
df2.head()
# Out:
#                                    name              category  price  \
# 0                Arcalion Tablets 200mg              Pharmacy   3.50
# 1                   Bactin Ointment 15g  Non-Prescribed Drugs  12.10
# 2  Becoplex With Iron Capsules 30 count  Non-Prescribed Drugs  22.16
# 3      Becoplex Liquid Iron Syrup 125ml  Non-Prescribed Drugs  19.80
# 4                  Becoplex Syrup 125ml  Non-Prescribed Drugs  18.30
#
#                                              img_url  \
# 0  https://mandcdrugstore.com/files/images/thumbs...
# 1  https://mandcdrugstore.com/files/images/thumbs...
# 2  https://mandcdrugstore.com/files/images/thumbs...
# 3  https://mandcdrugstore.com/files/images/thumbs...
# 4  https://mandcdrugstore.com/files/images/thumbs...
#
#                                      url product_id
# 0  https://mandcdrugstore.com/products/2          2
# 1  https://mandcdrugstore.com/products/3          3
# 2  https://mandcdrugstore.com/products/4          4
# ...

# %%
df2=df

# %%
df.to_csv('products_cleaned.csv', index=False)
